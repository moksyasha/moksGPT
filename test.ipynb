# %%
import torch

# --- 1. читаем текст ---
with open("data/input.txt", "r", encoding="utf-8") as f:
    text = f.read()

chars = set(text)
vocab_size = len(chars)
print(f"длина текста: {len(text):,} символов {chars}, {len(chars)}")
print(f"размер словаря: {vocab_size}")

ix = torch.randint(len(chars) - 4, (2,))
print(f"случайные стартовые позиции: {ix}")

a = torch.stack([torch.arange(i, i + 4) for i in ix])
print(f"результат stack: {a}, {a.shape}")
# Out:
# длина текста: 1,115,394 символов {'z', 'X', 'j', 'D', 'k', 'Q', 'L', ',', 'R', 'o', 'G', '$', 't', 'h', '.', 'l', ';', 'x', 'J', '3', 'v', 'C', 'B', 'V', 'U', 'T', 'p', 's', 'M', 'N', 'q', 'm', 'Y', 'a', 'K', '\n', 'A', 'Z', 'g', 'n', 'H', 'c', 'y', 'e', 'w', 'u', ':', '-', 'P', 'F', 'I', 'b', 'W', 'd', '&', 'E', '!', 'f', "'", ' ', 'O', 'r', 'i', 'S', '?'}, 65
# размер словаря: 65
# случайные стартовые позиции: tensor([40, 20])
# результат stack: tensor([[40, 41, 42, 43],
#         [20, 21, 22, 23]]), torch.Size([2, 4])

# %%
1e-1
# Out:
# 0.1
